# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle

# %%
file = open("data.pkl", "rb")
all_data = pickle.load(file)

# %%
len(all_data)
# Out:
# 100

# %%
arrival_times = [seq.t.to_numpy() for seq in all_data]
arrival_times[0][:10]
# Out:
# array([0.555286, 1.70091 , 5.57031 , 5.63253 , 5.63253 , 5.63253 ,
#        5.63253 , 5.63254 , 5.63254 , 5.7836  ])

# %%
seq_lengths = [len(seq) for seq in arrival_times]

# %%
t_end = 100

# %%
for data in all_data[:10]:
    plt.plot(data.t, data.index + 1)
plt.grid()
plt.show()
